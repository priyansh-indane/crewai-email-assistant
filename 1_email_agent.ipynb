# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from crewai import LLM

llm=LLM(
    model="gemini/gemini-2.5-flash",
    temperature=0.1
)
llm.call("Hello!!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from crewai import LLM
#       3 llm=LLM(
#       4     model="gemini/gemini-2.5-flash",
#       5     temperature=0.1
#       6 )
#       7 llm.call("Hello!!")
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\crewai\__init__.py:6
#       3 import urllib.request
#       4 import warnings
# ----> 6 from crewai.agent.core import Agent
#       7 from crewai.crew import Crew
#       8 from crewai.crews.crew_output import CrewOutput
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\crewai\agent\__init__.py:1
# ----> 1 from crewai.agent.core import Agent
#       2 from crewai.utilities.training_handler import CrewTrainingHandler
#       5 __all__ = ["Agent", "CrewTrainingHandler"]
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\crewai\agent\core.py:42
#      40 from crewai.agents.agent_builder.base_agent import BaseAgent
#      41 from crewai.agents.cache.cache_handler import CacheHandler
# ---> 42 from crewai.agents.crew_agent_executor import CrewAgentExecutor
#      43 from crewai.events.event_bus import crewai_event_bus
#      44 from crewai.events.types.agent_events import (
#      45     LiteAgentExecutionCompletedEvent,
#      46     LiteAgentExecutionErrorEvent,
#      47     LiteAgentExecutionStartedEvent,
#      48 )
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\crewai\agents\crew_agent_executor.py:16
#      13 from pydantic import BaseModel, GetCoreSchemaHandler, ValidationError
#      14 from pydantic_core import CoreSchema, core_schema
# ---> 16 from crewai.agents.agent_builder.base_agent_executor_mixin import CrewAgentExecutorMixin
#      17 from crewai.agents.parser import (
#      18     AgentAction,
#      19     AgentFinish,
#      20     OutputParserError,
#      21 )
#      22 from crewai.events.event_bus import crewai_event_bus
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\crewai\agents\agent_builder\base_agent_executor_mixin.py:7
#       4 from typing import TYPE_CHECKING
#       6 from crewai.agents.parser import AgentFinish
# ----> 7 from crewai.events.event_listener import event_listener
#       8 from crewai.memory.entity.entity_memory_item import EntityMemoryItem
#       9 from crewai.memory.long_term.long_term_memory_item import LongTermMemoryItem
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\crewai\events\event_listener.py:93
#      87 from crewai.events.types.tool_usage_events import (
#      88     ToolUsageErrorEvent,
#      89     ToolUsageFinishedEvent,
#      90     ToolUsageStartedEvent,
#      91 )
#      92 from crewai.events.utils.console_formatter import ConsoleFormatter
# ---> 93 from crewai.llm import LLM
#      94 from crewai.task import Task
#      95 from crewai.telemetry.telemetry import Telemetry
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\crewai\llm.py:85
#      82     from crewai.utilities.types import LLMMessage
#      84 try:
# ---> 85     import litellm
#      86     from litellm.exceptions import ContextWindowExceededError
#      87     from litellm.integrations.custom_logger import CustomLogger
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\litellm\__init__.py:1149
#    1146 from litellm.types.utils import LlmProviders
#    1148 ## Lazy loading this is not straightforward, will leave it here for now.
# -> 1149 from .main import *  # type: ignore
#    1151 # Skills API
#    1152 from .skills.main import (
#    1153     create_skill,
#    1154     acreate_skill,
#    (...)   1160     adelete_skill,
#    1161 )
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\litellm\main.py:219
#     217 from .llms.sap.chat.handler import GenAIHubOrchestration
#     218 from .llms.vertex_ai import vertex_ai_non_gemini
# --> 219 from .llms.vertex_ai.gemini.vertex_and_google_ai_studio_gemini import VertexLLM
#     220 from .llms.vertex_ai.gemini_embeddings.batch_embed_content_handler import (
#     221     GoogleBatchEmbeddings,
#     222 )
#     223 from .llms.vertex_ai.image_generation.image_generation_handler import (
#     224     VertexImageGeneration,
#     225 )
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\litellm\llms\vertex_ai\gemini\vertex_and_google_ai_studio_gemini.py:102
#      95 from ..common_utils import (
#      96     VertexAIError,
#      97     _build_json_schema,
#      98     _build_vertex_schema,
#      99     supports_response_json_schema,
#     100 )
#     101 from ..vertex_llm_base import VertexBase
# --> 102 from .transformation import (
#     103     _gemini_convert_messages_with_history,
#     104     async_transform_request_body,
#     105     sync_transform_request_body,
#     106 )
#     108 if TYPE_CHECKING:
#     109     from litellm.litellm_core_utils.litellm_logging import Logging as LiteLLMLoggingObj
#
# File ~\crewai-tutorial\.venv\Lib\site-packages\litellm\llms\vertex_ai\gemini\transformation.py:702
#     661     (
#     662     messages,
#     663     optional_params,
#    (...)    679         vertex_auth_header=vertex_auth_header,
#     680     )
#     683     return _transform_request_body(
#     684         messages=messages,
#     685         model=model,
#    (...)    689         optional_params=optional_params,
#     690     )
#     693 async def async_transform_request_body(
#     694     gemini_api_key: Optional[str],
#     695     messages: List[AllMessageValues],
#     696     api_base: Optional[str],
#     697     model: str,
#     698     client: Optional[AsyncHTTPHandler],
#     699     timeout: Optional[Union[float, httpx.Timeout]],
#     700     extra_headers: Optional[dict],
#     701     optional_params: dict,
# --> 702     logging_obj: litellm.litellm_core_utils.litellm_logging.Logging,  # type: ignore
#     703     custom_llm_provider: Literal["vertex_ai", "vertex_ai_beta", "gemini"],
#     704     litellm_params: dict,
#     705     vertex_project: Optional[str],
#     706     vertex_location: Optional[str],
#     707     vertex_auth_header: Optional[str],
#     708 ) -> RequestBody:
#     709     from ..context_caching.vertex_ai_context_caching import ContextCachingEndpoints
#     711     context_caching_endpoints = ContextCachingEndpoints()
#
# AttributeError: partially initialized module 'litellm' has no attribute 'litellm_core_utils' (most likely due to a circular import)

# %%
from crewai import Agent , Task , Crew

email_assistant= Agent(
    role="email assistant agent",
    goal="improve emails and make them sound clear and professional",
    backstory=" highly experienced skilled in writing email.",
    verbose=True,
    llm=llm


)

original_email=(" "
                "hello just wanted to tell that there is still some work left iam working on it thank you.")

email_task=Task(
    description=f"Take the following email and rewrite it into a professional version{original_email}",
    agent=email_assistant,
    expected_output="A professional written mail with proper formatting"
)

crew=Crew(
    agents=[email_assistant],
    tasks=[email_task],
    verbose=True
)

result=crew.kickoff()
print(result)
